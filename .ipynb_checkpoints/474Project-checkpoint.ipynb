# %%
import pandas as pd
import numpy as np

force_data = pd.read_csv("Police_Use_of_Force.csv")
shots_data = pd.read_csv("Shots_Fired.csv")

# %%
force_data.info()
shots_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32382 entries, 0 to 32381
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   X                              32382 non-null  float64
#  1   Y                              32382 non-null  float64
#  2   PoliceUseOfForceID             32382 non-null  int64
#  3   CaseNumber                     32382 non-null  object
#  4   ResponseDate                   32382 non-null  object
#  5   Problem                        31030 non-null  object
#  6   Is911Call                      31158 non-null  object
#  7   PrimaryOffense                 31161 non-null  object
#  8   SubjectInjury                  19692 non-null  object
#  9   ForceReportNumber              32382 non-null  int64
#  10  SubjectRole                    31081 non-null  object
#  11  SubjectRoleNumber              32299 non-null  float64
# ...

# %%
force_data.head()
# force_data.describe()
# Out:
#            X          Y  PoliceUseOfForceID CaseNumber  \
# 0 -93.278939  44.979240            20804298  08-007154
# 1 -93.286438  45.010118            20804299  08-018973
# 2 -93.264618  45.002528            20804300  08-019216
# 3 -93.257329  45.014978            20804301  08-026636
# 4 -93.269013  44.982137            20804302  08-032796
#
#              ResponseDate                   Problem Is911Call PrimaryOffense  \
# 0  2008/01/07 22:07:54+00        Suspicious Person         No         LOITER
# 1  2008/01/19 22:53:35+00       Suspicious Vehicle         No         RECVEH
# 2  2008/01/20 03:07:25+00          Unwanted Person        Yes         OBSTRU
# 3  2008/01/28 02:04:13+00  Traffic Law Enforcement         No         DWIREF
# 4  2008/02/03 00:50:46+00        Suspicious Person         No         OBSTRU
#
#   SubjectInjury  ForceReportNumber  ... TotalCityCallsForYear  \
# 0            No                  2  ...                322402
# ...

# %%
shots_data.head()
# shots_data.describe()
# Out:
#            X          Y  OBJECTID  longitude   latitude         Jurisdiction  \
# 0 -93.283588  44.957333         1 -93.283580  44.957325         MPD/MFD/HCMC
# 1 -93.300686  44.995218         2 -93.300678  44.995210         MPD/MFD/HCMC
# 2 -93.295645  44.999717         3 -93.295637  44.999709        MPD/MFD/North
# 3 -93.319099  45.012434         4 -93.319092  45.012426  Out of Jurisdiction
# 4 -93.288103  45.028467         5 -93.288095  45.028459        MPD/MFD/North
#
#   Master_Incident_Number              Division                     Problem  \
# 0              20-309298            Precinct 5    Sound of Shots Fired (P)
# 1              20-309468            Precinct 4    Sound of Shots Fired (P)
# 2              20-309469  Precinct 4 North PSA    Shooting Report Only (P)
# 3              20-309495   Out of Jurisdiction    Shooting Report Only (P)
# 4              20-309509  Precinct 4 North PSA  ShotSpotter Activation (P)
#
# ...
