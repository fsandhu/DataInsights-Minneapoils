# %%
#!pip install apyori
import pandas as pd
import numpy as np
#from apyori import apriori

stop_data = pd.read_csv("Police_Stop_Data.csv", low_memory=False)
force_data = pd.read_csv("Police_Use_of_Force.csv", low_memory=False)
shots_data = pd.read_csv("Shots_Fired.csv", low_memory=False)
weather_data = pd.read_csv("DailyPrecipReports_MN_2008-01-01_1.csv", low_memory=False)

# %%
stop_data.info()
force_data.info()
shots_data.info()
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175770 entries, 0 to 175769
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   OBJECTID              175770 non-null  int64
#  1   masterIncidentNumber  175770 non-null  object
#  2   responseDate          175770 non-null  object
#  3   reason                138280 non-null  object
#  4   problem               175770 non-null  object
#  5   callDisposition       173479 non-null  object
#  6   citationIssued        123304 non-null  object
#  7   personSearch          154403 non-null  object
#  8   vehicleSearch         154403 non-null  object
#  9   preRace               154403 non-null  object
#  10  race                  154403 non-null  object
#  11  gender                154403 non-null  object
#  12  lat                   175770 non-null  float64
#  13  long                  175770 non-null  float64
# ...

# %%
force_data.head()
# force_data.describe()
# Out:
#            X          Y  PoliceUseOfForceID CaseNumber  \
# 0 -93.278939  44.979240            20804298  08-007154
# 1 -93.286438  45.010118            20804299  08-018973
# 2 -93.264618  45.002528            20804300  08-019216
# 3 -93.257329  45.014978            20804301  08-026636
# 4 -93.269013  44.982137            20804302  08-032796
#
#              ResponseDate                   Problem Is911Call PrimaryOffense  \
# 0  2008/01/07 22:07:54+00        Suspicious Person         No         LOITER
# 1  2008/01/19 22:53:35+00       Suspicious Vehicle         No         RECVEH
# 2  2008/01/20 03:07:25+00          Unwanted Person        Yes         OBSTRU
# 3  2008/01/28 02:04:13+00  Traffic Law Enforcement         No         DWIREF
# 4  2008/02/03 00:50:46+00        Suspicious Person         No         OBSTRU
#
#   SubjectInjury  ForceReportNumber  ... TotalCityCallsForYear  \
# 0            No                  2  ...                322402
# ...

# %%
shots_data
# shots_data.describe()
# Out:
#                X          Y  OBJECTID  longitude   latitude  \
# 0     -93.283588  44.957333         1 -93.283580  44.957325
# 1     -93.300686  44.995218         2 -93.300678  44.995210
# 2     -93.295645  44.999717         3 -93.295637  44.999709
# 3     -93.319099  45.012434         4 -93.319092  45.012426
# 4     -93.288103  45.028467         5 -93.288095  45.028459
# ...          ...        ...       ...        ...        ...
# 69281 -93.312710  44.993352     69282 -93.312703  44.993344
# 69282 -93.308231  44.992294     69283 -93.308224  44.992286
# 69283 -93.309503  44.997876     69284 -93.309495  44.997868
# 69284 -93.309717  44.982126     69285 -93.309709  44.982118
# 69285 -93.296897  45.023093     69286 -93.296889  45.023085
#
#               Jurisdiction Master_Incident_Number              Division  \
# 0             MPD/MFD/HCMC              20-309298            Precinct 5
# 1             MPD/MFD/HCMC              20-309468            Precinct 4
# ...

# %%
stop_data
# stop_data.describe()
# Out:
#         OBJECTID masterIncidentNumber            responseDate  \
# 0              1            16-395258  2016/10/31 22:40:47+00
# 1              2            16-395296  2016/10/31 23:06:36+00
# 2              3            16-395326  2016/10/31 23:20:54+00
# 3              4            16-395328  2016/10/31 23:23:20+00
# 4              5            16-395333  2016/10/31 23:26:05+00
# ...          ...                  ...                     ...
# 175765    175766            21-065728  2021/03/31 01:53:53+00
# 175766    175767            21-065766  2021/03/31 03:13:35+00
# 175767    175768            21-065771  2021/03/31 03:32:31+00
# 175768    175769            21-065785  2021/03/31 04:22:30+00
# 175769    175770            21-065798  2021/03/31 05:15:42+00
#
#                   reason                      problem       callDisposition  \
# 0                    NaN        Suspicious Person (P)           BKG-Booking
# ...

# %%
index = []
i = 0
for ind in weather_data.index:
    if not "Minneapolis" in str(weather_data['StationName'][ind]):
        index.append(ind)
minneapolis_weather_data = weather_data.drop(index)

# %%
index = []
for ind in shots_data.index:
    if "Out of Jurisdiction" in str(shots_data['Jurisdiction'][ind]):
        index.append(ind)
shots_data_post = shots_data.drop(index)

# %%
index = []
for ind in force_data.index:
    if pd.isnull(force_data['Problem'][ind]) and pd.isnull(force_data['PrimaryOffense'][ind]):
        index.append(ind)
force_data_post = force_data.drop(index)
values = {'SubjectInjury': 'No'}
force_data_post.fillna(value=values)
# Out:
#                X          Y  PoliceUseOfForceID CaseNumber  \
# 0     -93.278939  44.979240            20804298  08-007154
# 1     -93.286438  45.010118            20804299  08-018973
# 2     -93.264618  45.002528            20804300  08-019216
# 3     -93.257329  45.014978            20804301  08-026636
# 4     -93.269013  44.982137            20804302  08-032796
# ...          ...        ...                 ...        ...
# 31222 -93.238629  44.948363            20835520  21-026551
# 31223 -93.297474  45.020378            20835521  21-027031
# 31224 -93.287459  44.948366            20835522  21-041507
# 31225 -93.217423  44.971486            20835523  21-053545
# 31226 -93.273109  44.979187            20835524  21-058248
#
#                  ResponseDate                    Problem Is911Call  \
# 0      2008/01/07 22:07:54+00         Suspicious Person         No
# 1      2008/01/19 22:53:35+00        Suspicious Vehicle         No
# ...

# %%
#TODO: decide what to do with null reasons

#index = []
#for ind in stop_data.index:
#    if pd.isnull(stop_data['reason'][ind]):
#        index.append(ind)
#stop_data_post = stop_data.drop(index)
values = {'citationIssued': 'NO'}
stop_data.fillna(value=values)
# Out:
#         OBJECTID masterIncidentNumber            responseDate  \
# 0              1            16-395258  2016/10/31 22:40:47+00
# 1              2            16-395296  2016/10/31 23:06:36+00
# 2              3            16-395326  2016/10/31 23:20:54+00
# 3              4            16-395328  2016/10/31 23:23:20+00
# 4              5            16-395333  2016/10/31 23:26:05+00
# ...          ...                  ...                     ...
# 175765    175766            21-065728  2021/03/31 01:53:53+00
# 175766    175767            21-065766  2021/03/31 03:13:35+00
# 175767    175768            21-065771  2021/03/31 03:32:31+00
# 175768    175769            21-065785  2021/03/31 04:22:30+00
# 175769    175770            21-065798  2021/03/31 05:15:42+00
#
#                   reason                      problem       callDisposition  \
# 0                    NaN        Suspicious Person (P)           BKG-Booking
# ...

# %%
#TODO: could not get it to find the module

#entries = shots_data_post.to_numpy()
#rules = apriori(entries, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)
#results = list(rules)
#rule_results = pd.DataFrame(results)
#rule_results.head()
